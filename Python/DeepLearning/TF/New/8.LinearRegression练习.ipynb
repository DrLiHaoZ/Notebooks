# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# 假设原始的函数关系为：
# $y=2x^2+3x+4$
# 即：
# $y=w_1  x^2 + w_2  x + b$

# %%
LENGTH = 100
X = tf.random.normal(shape = (LENGTH,))
noise = tf.random.normal(shape=(LENGTH,))
y = 2 * X ** 2 + 3 * X + 4 + noise
true_y = 2 * X ** 2 + 3 * X + 4

plt.figure()
plt.plot(X,y,'r.')
plt.plot(X,true_y,'b.')
plt.legend(['real_y','true_y'])
plt.show()

# %%
class Model:
    def __init__(self) :
        self.w1 = tf.Variable(10.0)
        self.w2 = tf.Variable(10.0)
        self.b = tf.Variable(10.0)
    def __call__(self,x):
        return self.w1 * x **2  + self.w2 * x + self.b

# %%
def loss(y,pred_y):
    return tf.reduce_mean(tf.square(y - pred_y))

def train(model,X,y,lr = 0.01):
    with tf.GradientTape as tape:
        current_loss = loss(y,model(X))
    d_w1 = tape.gradient(current_loss, model.w1)
    d_w2 = tape.gradient(current_loss, model.w2)
    d_b = tape.gradient(current_loss, model.b)

    model.w1.assign_sub(lr * d_w1)
    model.w2.assign_sub(lr * d_w2)
    model.b.assign_sub(lr * d_b)

# %%
model = Model()
w1s,w2s,bs = [], [], []
epochs = 20
for epoch in range(epochs):
    w1s.append(model.w1.numpy())  
    w2s.append(model.w2.numpy())
    bs.append(model.b.numpy())

    current_loss = loss(y, model(X))

    train(model, X, y, lr=0.01)
    print(f"Epoch {epoch}: Loss: {current_loss.numpy()}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/75/2jbtwxss6vj9srgqqplsb0v40000gn/T/ipykernel_86748/2830004716.py in <module>
#       9     current_loss = loss(y, model(X))
#      10
# ---> 11     train(model, X, y, lr=0.01)
#      12     print(f"Epoch {epoch}: Loss: {current_loss.numpy()}")
#
# /var/folders/75/2jbtwxss6vj9srgqqplsb0v40000gn/T/ipykernel_86748/834270976.py in train(model, X, y, lr)
#       3
#       4 def train(model,X,y,lr = 0.01):
# ----> 5     with tf.GradientTape as tape:
#       6         current_loss = loss(y,model(X))
#       7     d_w1 = tape.gradient(current_loss, model.w1)
#
# AttributeError: __enter__
