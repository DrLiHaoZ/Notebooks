# %%
# AutoDiff

# %% [markdown]
# - Finite differences
#   - $f:R^n \rightarrow R$
#   - $ \frac {\partial f}{\partial x_i} = \frac {f(x + he_i)-f(x)}{h}$

# %%
import numpy 
import sympy
x = sympy.Symbol('x')
t = sympy.Symbol('t')
y = sympy.cos(x ** 2 + t )
y
sympy.diff(y,t)
# Out:
# -sin(t + x**2)

# %%
x = sympy.Symbol('x')
y = x ** 2 - 4 
sympy.solve(y,x)
# Out:
# [-2, 2]

# %% [markdown]
# - Auto Diff
#   - Forward mode
