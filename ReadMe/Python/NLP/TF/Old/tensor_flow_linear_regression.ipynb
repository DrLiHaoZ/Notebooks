# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
learning_rate = 0.01
epochs = 200

# %%
n_samples = 30
train_x = np.linspace(0,20,n_samples)
train_y = 3 * train_x + 4 * np.random.randn(n_samples)
print(train_y)
# Out:
# [-0.87907598 -0.30535382  1.00324392  7.36294396  8.22067331  7.75424812
#  16.40306951 15.88105659 13.71439609 14.20917058 17.27415694 18.56786263
#  26.60830815 24.95184409 26.01079824 25.58662749 39.38298098 33.41492326
#  36.44859034 40.99124282 36.04911038 46.94768288 48.1951746  46.18118791
#  50.39022997 45.98393444 55.49100703 54.43889932 60.25087981 57.58820299]

# %%
plt.plot(train_x,train_y,"o")
plt.plot(train_x,3*train_x)
plt.show()
