# %%
import numpy as np
import random
import seaborn as sns

# %%
a = np.random.normal(loc = 10,scale = 2,size = 1000)
b = np.random.normal(loc = 10,scale = 2,size = 1000)
sns.kdeplot(a)
sns.kdeplot(b)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
chi2_sim = ((a - b)**2 / a)
chi2 = (np.random.normal(loc = 0,scale=1,size = 1000))**2

sns.kdeplot(chi2_sim)
sns.kdeplot(chi2)
# Out:
# <AxesSubplot:ylabel='Density'>
