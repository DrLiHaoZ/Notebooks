# %%
import numpy as np
from numpy import linalg
import matplotlib.pyplot as plt

# %%
a = np.array([[2,0],[0,2]])
v,b = linalg.eig(a)
print(v)
print(b)
# Out:
# [2. 2.]
# [[1. 0.]
#  [0. 1.]]

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/abrobrown/Desktop/MindmapDXY/ReadMe/Python/线性代数/6.特征向量.ipynb Cell 3' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/abrobrown/Desktop/MindmapDXY/ReadMe/Python/%E7%BA%BF%E6%80%A7%E4%BB%A3%E6%95%B0/6.%E7%89%B9%E5%BE%81%E5%90%91%E9%87%8F.ipynb#ch0000002?line=0'>1</a> origin = np.array([[0,0],[0,0]])
# ----> <a href='vscode-notebook-cell:/Users/abrobrown/Desktop/MindmapDXY/ReadMe/Python/%E7%BA%BF%E6%80%A7%E4%BB%A3%E6%95%B0/6.%E7%89%B9%E5%BE%81%E5%90%91%E9%87%8F.ipynb#ch0000002?line=1'>2</a> plt.quiver([0,0],[0,0],[10,0],[0,20],color = [1,2],scale = 100)
#
# File ~/miniforge3/lib/python3.9/site-packages/matplotlib/pyplot.py:2788, in quiver(data, *args, **kwargs)
# ...
